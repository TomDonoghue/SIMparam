# %% [markdown]
# # Simulations with Model Violations: Aperiodic
#
# Words, words, words.

# %%
from collections import Counter

import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import spearmanr

from fooof import FOOOF, FOOOFGroup, fit_fooof_group_3d
from fooof.plts import plot_spectrum
from fooof.sim import gen_power_spectrum, gen_group_power_spectra

# %%
# General Simulation Settings
f_range = [1, 100]
f_res = 0.25

# %% [markdown]
# ## Knee Sims

# %%
# Test generate a power spectrum
ap = [1, 100, 2]
osc = [10, 0.3, 1]
nlv = 0.

fs, ps = gen_power_spectrum(f_range, ap, osc, nlv, f_res)

# %%
# Plot example synthesized power spectrum
plot_spectrum(fs, ps, True, True)

# %%
fm = FOOOF(aperiodic_mode='knee')
fm.report(fs, ps, plt_log=False)
# Out:
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                        The model was run on the frequency range 1 - 100 Hz
#                                  Frequency Resolution is 0.25 Hz
#
#                          Aperiodic Parameters (offset, knee, exponent):
#                                      1.0007, 100.0560, 2.0004
#
#                                        1 peaks were found:
#                                 CF:  10.00, PW:  0.299, BW:  1.98
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 1.0000
#                                 Root mean squared error is 0.0002
#
# ==================================================================================================
